# %%
import df_graph
import numpy as np
import pandas as pd

# %%
A = np.linspace(0, 1)
B = [x**2 for x in A]
C = [np.cos(2*np.pi*x) for x in A]
S = [np.sin(2*np.pi*x) for x in A]
E = np.random.rand(len(A))/20+0.1
df = pd.DataFrame([A, B, C, S, E], index=[
                  "x", "squarex", "cosx", "sinx", "error"]).T

# %%
df.head()
# Out:
#           x   squarex      cosx      sinx     error
# 0  0.000000  0.000000  1.000000  0.000000  0.113003
# 1  0.020408  0.000416  0.991790  0.127877  0.121011
# 2  0.040816  0.001666  0.967295  0.253655  0.132708
# 3  0.061224  0.003748  0.926917  0.375267  0.142742
# 4  0.081633  0.006664  0.871319  0.490718  0.106174

# %%
df_graph.multiLegend(df,'x',['cosx'])

# %%
df_graph.multiLegend2(df,"x",["squarex"],["cosx","sinx"])

# %%
df_graph.multiLegend_wError(df,'x',['sinx'],['error'])

# %%
df_graph.multiAxes(df,'x',['squarex','sinx','cosx'])

# %%
df_graph.multiPlots(df,'x',['squarex','sinx','cosx'])
